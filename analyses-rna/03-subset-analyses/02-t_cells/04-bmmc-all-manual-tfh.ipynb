# %% [markdown]
# ## T cells of interest: TH1, TH2, TH17, TFH, TFR
# > No verification for TH1/TH2

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('../../../data/rna/bmmc-celltypes/bmmc-t_cell-processed-harmony.h5ad')

# %%
sc.pl.tsne(adata, color='aifi_celltype_l3', size=1)

# %%
sc.pl.umap(adata, color='aifi_celltype_l3', size=1)

# %%
sc.pl.tsne(adata,
           color=[
                  'CXCR5', 'IFNG',
                  'FOXP3', 'IL2', 'IL4',
                  'IL5', 'IL13',
                  'IL17A', 'IL22',
                  'PDCD1', 'IL21',
                  'ICOS', 'BCL6',
                  'SOSTDC1', 'CD40LG'],
           size=1,
           use_raw=False, vmax='p99', cmap='Reds')
