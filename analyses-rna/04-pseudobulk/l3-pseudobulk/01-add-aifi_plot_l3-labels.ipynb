# %% [markdown]
# # 2025-10-31: Change plot label L3
# ### By [Aishwarya Chander](aishwarya.chander@alleninstitute.org), High Resolution Translational Immunology, Allen Institute for Immunology
#
# **Main aim**: In this notebook, I'm adjusting my cell type labels from `aifi_label_l3` to `aifi_plot_l3` to enable ease of plotting. This was already done for `L2` in the object building step.

# %%
import scanpy as sc
import pandas as pd

path = '../../../data/rna/'

# %% [markdown]
# ## For PBMCs

# %%
adata = sc.read_h5ad(path+'final-objects/final-pbmc-raw.h5ad')

# %%
l3_to_plot3 = {
    # T cell - CD8
    "CD8aa": "CD8aa",
    "Core naive CD8 T cell": "CD8 T Naive Core",
    "SOX4+ naive CD8 T cell": "CD8 T Naive SOX4+",
    "ISG+ naive CD8 T cell": "CD8 T Naive ISG+",
    "CM CD8 T cell": "CD8 T CM",
    "GZMK+ CD27+ EM CD8 T cell": "CD8 T EM GZMK+ CD27+",
    "GZMK- CD27+ EM CD8 T cell": "CD8 T EM GZMK- CD27+",
    "KLRF1+ GZMB+ CD27- EM CD8 T cell": "CD8 T EM KLRF1+ GZMB+",
    "KLRF1- GZMB+ CD27- EM CD8 T cell": "CD8 T EM KLRF1- GZMB+",
    "ISG+ memory CD8 T cell": "CD8 T Mem ISG+",
    # T cell - CD4
    "Core naive CD4 T cell": "CD4 T Naive Core",
    "SOX4+ naive CD4 T cell": "CD4 T Naive SOX4+",
    "ISG+ naive CD4 T cell": "CD4 T Naive ISG+",
    "CM CD4 T cell": "CD4 T CM",
    "GZMB- CD27+ EM CD4 T cell": "CD4 T EM GZMB- CD27+",
    "GZMB- CD27- EM CD4 T cell": "CD4 T EM GZMB- CD27-",
    "KLRF1- GZMB+ CD27- memory CD4 T cell": "CD4 T Mem KLRF1- GZMB+",
    "ISG+ memory CD4 T cell": "CD4 T Mem ISG+",
    # T cell - DN
    "DN T cell": "DN T",
    # T cell - MAIT
    "CD4 MAIT": "CD4 MAIT",
    "CD8 MAIT": "CD8 MAIT",
    "ISG+ MAIT": "MAIT ISG+",
    # T cell - Treg
    "Naive CD4 Treg": "Treg Naive",
    "Memory CD4 Treg": "Treg CD4 Mem",
    "GZMK+ memory CD4 Treg": "Treg CD4 Mem GZMK+",
    "KLRB1+ memory CD4 Treg": "Treg CD4 Mem KLRB1+",
    "Memory CD8 Treg": "Treg CD8 Mem",
    "KLRB1+ memory CD8 Treg": "Treg CD8 Mem KLRB1+",
    # T cell - gdT
    "Naive Vd1 gdT": "gdT Vd1 Naive",
    "SOX4+ Vd1 gdT": "gdT Vd1 SOX4+",
    "KLRF1+ effector Vd1 gdT": "gdT Vd1 Eff KLRF1+",
    "KLRF1- effector Vd1 gdT": "gdT Vd1 Eff KLRF1-",
    "GZMK+ Vd2 gdT": "gdT Vd2 GZMK+",
    "GZMB+ Vd2 gdT": "gdT Vd2 GZMB+",
    # T cell - Proliferating
    "Proliferating T cell": "Prolif T",
    # B cell
    "Core naive B cell": "Naive B Core",
    "ISG+ naive B cell": "Naive B ISG+",
    "Transitional B cell": "Trans B",
    "Early memory B cell": "Mem B Early",
    "Core memory B cell": "Mem B Core",
    "CD95 memory B cell": "Mem B CD95",
    "Activated memory B cell": "Mem B Activated",
    "Type 2 polarized memory B cell": "Mem B Type2",
    "CD27+ effector B cell": "Eff B CD27+",
    "CD27- effector B cell": "Eff B CD27-",
    "Plasma cell": "Plasma",
    # Monocyte
    "Core CD14 monocyte": "CD14 Mono Core",
    "IL1B+ CD14 monocyte": "CD14 Mono IL1B+",
    "ISG+ CD14 monocyte": "CD14 Mono ISG+",
    "Core CD16 monocyte": "CD16 Mono Core",
    "C1Q+ CD16 monocyte": "CD16 Mono C1Q+",
    "ISG+ CD16 monocyte": "CD16 Mono ISG+",
    "Intermediate monocyte": "Int Mono",
    # NK cell
    "CD56bright NK cell": "CD56br NK",
    "GZMK+ CD56dim NK cell": "CD56dim NK GZMK+",
    "GZMK- CD56dim NK cell": "CD56dim NK GZMK-",
    "ISG+ CD56dim NK cell": "CD56dim NK ISG+",
    "Adaptive NK cell": "NK Adaptive",
    "Proliferating NK cell": "Prolif NK",
    # Dendritic cell
    "ASDC": "ASDC",
    "cDC1": "cDC1",
    "CD14+ cDC2": "cDC2 CD14+",
    "HLA-DRhi cDC2": "cDC2 HLA-DRhi",
    "ISG+ cDC2": "cDC2 ISG+",
    "pDC": "pDC",
    # Progenitor
    "CLP cell": "CLP",
    "CMP cell": "CMP",
    "BaEoMaP cell": "BaEoMaP",
    # Other
    "ILC": "ILC",
    "Platelet": "Platelet",
}

adata.obs["aifi_plot_l3"] = (
    adata.obs["aifi_label_l3"]
    .map(l3_to_plot3)
    .astype("category")
    .cat.remove_unused_categories()
)

# %%
adata.write(path+'final-objects/final-pbmc-raw.h5ad')
adata.obs.to_parquet(path+'final-objects/final-pbmc-metadata.parquet')

# %% [markdown]
# ## For BMMCs

# %%
adata = sc.read_h5ad(path+'final-objects/final-bmmc-raw.h5ad')

# %%
l3_to_plot3 = {
    # T cell - CD4
    "Core naive CD4 T cell": "CD4 T Naive Core",
    "ISG+ naive CD4 T cell": "CD4 T Naive ISG+",
    "CD4 Memory T cell": "CD4 T Mem Core",
    "CM CD4 T cell": "CD4 T CM",
    "CD4 Effector Memory 1 T cell": "CD4 T EM1",
    "CD4 Effector Memory 2 T cell": "CD4 T EM2",
    # T cell - CD8
    "Core naive CD8 T cell ": "CD8 T Naive Core",
    "CD8 Effector Memory 1 T cell": "CD8 T EM1",
    "CD8 Effector Memory 2 T cell": "CD8 T EM2",
    "Tissue resident CD8 T cell": "CD8 T Tissue Res",
    # T cell - Treg
    "CD4 Treg": "Treg",
    # T cell - Other
    "DN T cell": "DN T",
    "gdT": "gdT",
    "MAIT": "MAIT",
    "Proliferating T cell": "Prolif T",
    # B cell
    "Heavy chain recombinant precursor B cell": "Pre B Heavy",
    "Light chain recombinant precursor B cell": "Pre B Light",
    "ISG+ precursor B cell": "Pre B ISG+",
    "Proliferating precursor B cell": "Pre B Prolif",
    "Transitional B cell": "Trans B Core",
    "ISG+ Transitional B cell": "Trans B ISG+",
    "Core naive B cell": "Naive B Core",
    "ISG+ naive B cell": "Naive B ISG+",
    "Core memory B cell": "Mem B Core",
    "CD95 memory B cell": "Mem B CD95",
    # Plasma
    "Plasma (Non-malignant)": "Plasma (Non-malignant)",
    "Plasma (Malignant)": "Plasma (Malignant)",
    # Monocyte
    "Core CD14 monocyte": "CD14 Mono Core",
    "ISG+ CD14 monocyte": "CD14 Mono ISG+",
    "Core CD16 monocyte": "CD16 Mono Core",
    "Intermediate monocyte": "Int Mono",
    "Precursor monocyte": "Pre Mono Core",
    "Proliferating precursor monocyte": "Pre Mono Prolif",
    # NK cell
    "CD56bright NK cell": "CD56br NK",
    "GZMK+ CD56dim NK cell": "CD56dim NK GZMK+",
    "GZMK- CD56dim NK cell": "CD56dim NK GZMK-",
    "ISG+ CD56dim NK cell": "CD56dim NK ISG+",
    "Adaptive NK cell": "NK Adaptive",
    "Effector NK cell": "NK Effector",
    "Tissue resident NK cell": "NK Tissue Res",
    "Proliferating NK cell ": "Prolif NK",
    # Dendritic cell
    "ASDC": "ASDC",
    "cDC1": "cDC1",
    "cDC2": "cDC2 Core",
    "ISG+ cDC2": "cDC2 ISG+",
    "pDC": "pDC",
    # Progenitor - B cell
    "Precursor B cell progenitor": "Prog B Pre",
    "B cell progenitor": "Prog B",
    "Mature B cell progenitor": "Prog B Mature",
    # Progenitor - Lymphoid
    "Common lymphoid progenitor": "CLP",
    "Lymphoid-primed multipotent progenitor": "LMPP",
    # Progenitor - Myeloid
    "Common myeloid progenitor": "CMP Core",
    "Granulocyte progenitor": "CMP Gran",
    "BaEoMaP cell": "BaEoMaP",
    "Megakaryocyte-erythroid progenitor cell": "MEP",
    # Progenitor - Erythroid
    "Precursor erythroid progenitor": "Pre Prog Ery",
    "Mature erythroid progenitor": "Prog Ery",
    "Proliferating erythroid progenitor": "Prog Ery Prolif",
    # Progenitor - Megakaryocyte
    "Megakaryocyte progenitor cell": "Prog MK",
    # Progenitor - Dendritic cell
    "cDC commited DC progenitor": "Prog DC cDC",
    "pDC committed DC progenitor": "Prog DC pDC",
    # Progenitor - HSPC
    "Hematopoetic stem and progenitor": "HSPC Stem",
    "Multipotential HSPC": "HSPC Multi",
    "Proliferating HSPC": "HSPC Prolif",
}

adata.obs["aifi_plot_l3"] = (
    adata.obs["aifi_label_l3"]
    .map(l3_to_plot3)
    .astype("category")
    .cat.remove_unused_categories()
)

# %%
adata.write(path+'final-objects/final-bmmc-raw.h5ad')
adata.obs.to_parquet(path+'final-objects/final-bmmc-metadata.parquet')
