# %%
import scanpy as sc
sc.settings.figdir='../../data/figure-outputs/supplementary-1'

sc.settings.set_figure_params(
    dpi=80,
    facecolor='white',
    frameon=False,
    dpi_save=400,
    figsize=(6, 6),
    format='png'
)

# %%
plasma_pretx = sc.read_h5ad('../../data/figure-inputs/scrna_objects/plasma-pretx-no_harmony.h5ad', backed='r')
sc.pl.umap(plasma_pretx, 
           color = ['plasma_labels_l3_numeric', 'subject.subjectGuid'], 
           title = ['', ''], 
           size = 10, wspace=0.2, 
           save='sup_1d-e.png')
# Out:
# WARNING: saving figure to file ../outputs/supplementary-1/umapsup_1d-e.png
