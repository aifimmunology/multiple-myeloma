# %%
import scanpy as sc

sc.settings.figdir = '../../data/figure-outputs/supplementary-1'

sc.settings.set_figure_params(
    dpi=200,
    facecolor='white',
    frameon=False,
    fontsize=15,
    dpi_save=400,
    figsize=(6,6),
    format='png'
)

# %%
adata = sc.read_h5ad('../../data/figure-inputs/scrna_objects/pretx-plasma-paga.h5ad', backed='r')

# %%
sc.pl.rank_genes_groups_dotplot(adata, groupby='plasma_labels_l3',
                                n_genes=6, standard_scale='var', cmap='Reds', save='sup_1f.png')
# Out:
# WARNING: saving figure to file ../outputs/supplementary-1/dotplot_sup_1f.png

# %%
sc.pl.rank_genes_groups_dotplot(adata, groupby='plasma_labels_l3', 
                                n_genes=6, standard_scale='var', cmap='Reds', save='sup_1f.pdf')
# Out:
# WARNING: saving figure to file ../outputs/supplementary-1/dotplot_sup_1f.pdf
