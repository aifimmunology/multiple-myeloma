# %%
source('../utilities/functions/gex-violins-colors.R')

# %%
p <- plot_expression_violins(
  metadata_path = "../../data/figure-inputs/metadata/bmmc_sample_kit_metadata.csv",
  files_dir = "../../data/figure-inputs/bmmc_l3_lognorm_gexp_celltypes_per_samplekit",
  gene_list = c("CCR1", "CCL5"),
  celltypes = c("CD14 Mono Core", "CD8 T Tissue Res", "Int Mono", "NK Tissue Res", "Plasma (Malignant)", "Plasma (Non-malignant)"),
  visits = c("PreTx", "Healthy"),
  paired_visits = NULL,
  unpaired_visit = "Healthy",
  plot_width = 9,
  plot_height = 5,
  base_size = 12,
  title = NULL,
  subtitle = ''
)
p
# Out:
# plot without title

# %%
ggsave("../../data/figure-outputs/figure-2/fig_2n.pdf", plot = p, width = 9, height = 5, dpi = 200, device = cairo_pdf)
