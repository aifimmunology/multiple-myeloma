# %%
source('../utilities/functions/gex-violins-colors.R')

# %%
p <- plot_expression_violins(
  metadata_path = "../../data/figure-inputs/metadata/bmmc_sample_kit_metadata.csv",
  files_dir = "../../data/figure-inputs/bmmc_l3_lognorm_gexp_celltypes_per_samplekit",
  gene_list = c("CCL28", "CCR10"),
  celltypes = c("HSPC Stem", "HSPC Multi", "CLP", "Plasma (Malignant)", "Plasma (Non-malignant)"),
  visits = c("PreTx", "Healthy"),
  paired_visits = NULL,
  unpaired_visit = "Healthy",
  plot_width = 7.5,
  plot_height = 5,
  base_size = 12,
  title = NULL,
  subtitle = ''
)
p
# Out:
# plot without title

# %%
ggsave("../../data/figure-outputs/figure-2/fig_2o.pdf", plot = p, width = 7.5, height = 5, dpi = 200, device = cairo_pdf)
