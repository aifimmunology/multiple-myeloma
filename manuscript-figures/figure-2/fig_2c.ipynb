# %%
import scanpy as sc

# Set the output directory
sc.settings.figdir = '../../data/figure-outputs/figure-2'

# Set the visual parameters
sc.settings.set_figure_params(
    dpi=80,
    facecolor='white',
    frameon=False,
    dpi_save=200,
    figsize=(6,6),
    format='png'
)

# %%
adata = sc.read_h5ad('../../data/figure-inputs/scrna_objects/pretx-plasma-paga.h5ad')

# %%
sc.pl.umap(
    adata,
    color='plasma_labels_l3',
    size=12,
    legend_loc='on data',
    legend_fontsize=15,
    title='',
    save='fig_2c.png'
)
# Out:
# WARNING: saving figure to file ../outputs/figure-2/umapfig_2c.png
