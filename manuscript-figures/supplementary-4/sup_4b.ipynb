# %%
source('../utilities/functions/deg-volcanos.R')

# %%
plot_width <- 7.5
plot_height <- 5.5
plot_dpi <- 200

p <- plot_volcano_publication(
  input_deg_res = "../../data/figure-inputs/l3-deseq2_results/deseq2_results_bmmc_PreTx_vs_Healthy.csv",
  selected_celltypes = c("HSPC Stem", "HSPC Multi", "LMPP", "CMP Gran", "CMP Core"),
  ncols = 3,
  max_overlaps = 10,
  timepoint_1 = "PreTx",
  timepoint_2 = "Healthy"
)
options(repr.plot.width = plot_width, repr.plot.height = plot_height)
p

ggsave("../../data/figure-outputs/supplementary-4/sup_4b.pdf", plot = p, width = plot_width, height = plot_height, dpi = plot_dpi, device = cairo_pdf)
# Out:
# Warning message:
# “ggrepel: 16 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 535 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 257 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 343 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 20 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 538 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 263 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 346 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
