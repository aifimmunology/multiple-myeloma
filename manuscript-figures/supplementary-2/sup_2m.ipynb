# %%
source('../utilities/functions/gex-violins-colors.R')

# %%
p <- plot_expression_violins(
  metadata_path = '../../data/figure-inputs/metadata/pbmc_sample_kit_metadata.csv',
  files_dir = '../../data/figure-inputs/pbmc_l3_lognorm_gexp_celltypes_per_samplekit',
  gene_list = c('CCR1'),
  celltypes = c('CD14 Mono Core',
  'CD14 Mono IL1B+',
  'CD14 Mono ISG+'),
  visits = c('PreTx', 'PI2C', 'EI', 'ASCT60d', 'ASCT1y', 'ASCT2y', 'Healthy'),
  paired_visits = c('PreTx', 'PI2C', 'EI', 'ASCT60d', 'ASCT1y', 'ASCT2y'),
  unpaired_visit = 'Healthy',
  plot_width = 6,
  plot_height = 3,
  base_size = 10, 
  step.increase = 0.06,
  title = '',
  pval_colors = c('maroon', 'seagreen', 'gray30', 'gray50'),
  line_size = 0.6
)
p

ggsave("../../data/figure-outputs/supplementary-2/sup_2m_p1.pdf", plot = p, width = 6, height = 3, dpi = 200, device = cairo_pdf)
# Out:
# plot without title

# %%
p <- plot_expression_violins(
  metadata_path = '../../data/figure-inputs/metadata/pbmc_sample_kit_metadata.csv',
  files_dir = '../../data/figure-inputs/pbmc_l3_lognorm_gexp_celltypes_per_samplekit',
  gene_list = c('CCR1'),
  celltypes = c('Int Mono',
  'CD16 Mono Core',
  'CD16 Mono ISG+'),
  visits = c('PreTx', 'PI2C', 'EI', 'ASCT60d', 'ASCT1y', 'ASCT2y', 'Healthy'),
  paired_visits = c('PreTx', 'PI2C', 'EI', 'ASCT60d', 'ASCT1y', 'ASCT2y'),
  unpaired_visit = 'Healthy',
  plot_width = 6,
  plot_height = 3,
  base_size = 10, 
  step.increase = 0.06,
  title = '',
  pval_colors = c('maroon', 'seagreen', 'gray30', 'gray50'),
  line_size = 0.6
)
p
ggsave("../../data/figure-outputs/supplementary-2/sup_2m_p2.pdf", plot = p, width = 6, height = 3, dpi = 200, device = cairo_pdf)
# Out:
# plot without title
