# %%
source('../utilities/functions/gex-violins-colors.R')

# %%
p <- plot_expression_violins(
  metadata_path = "../../data/figure-inputs/metadata/bmmc_sample_kit_metadata.csv",
  files_dir = "../../data/figure-inputs/bmmc_l3_lognorm_gexp_celltypes_per_samplekit",
  gene_list = c("CCR1"),
  celltypes = c(
    "CD16 Mono Core",
    "Int Mono"
  ),
  visits = c("PreTx", "EI", "ASCT90d", "ASCT1y", "ASCT2y", "Healthy"),
  paired_visits = c("PreTx", "EI", "ASCT90d", "ASCT1y", "ASCT2y"),
  unpaired_visit = "Healthy",
  plot_width = 6,
  plot_height = 4,
  base_size = 12,
  step.increase = 0.06,
  title = "",
  pval_colors = c("maroon", "seagreen", "gray30", "gray50"),
  line_size = 0.6
)
p
ggsave("../../data/figure-outputs/figure-3/fig_3g_p1.pdf", plot = p, width = 6, height = 4, dpi = 200, device = cairo_pdf)
# Out:
# plot without title

# %%
p <- plot_expression_violins(
  metadata_path = "../../data/figure-inputs/metadata/bmmc_sample_kit_metadata.csv",
  files_dir = "../../data/figure-inputs/bmmc_l3_lognorm_gexp_celltypes_per_samplekit",
  gene_list = c("CCR1"),
  celltypes = c(
    "CD14 Mono Core",
    "CD14 Mono ISG+"
  ),
  visits = c("PreTx", "EI", "ASCT90d", "ASCT1y", "ASCT2y", "Healthy"),
  paired_visits = c("PreTx", "EI", "ASCT90d", "ASCT1y", "ASCT2y"),
  unpaired_visit = "Healthy",
  plot_width = 6,
  plot_height = 4,
  base_size = 12,
  step.increase = 0.06,
  title = "",
  pval_colors = c("maroon", "seagreen", "gray30", "gray50"),
  line_size = 0.6
)
p
ggsave("../../data/figure-outputs/figure-3/fig_3g_p2.pdf", plot = p, width = 6, height = 4, dpi = 200, device = cairo_pdf)
# Out:
# plot without title
